# %%
import pandas as pd

url1 = "https://github.com/KhalPrawira/Big-Data_Assignment/raw/refs/heads/main/Dataset/global%20air%20pollution%20dataset.csv"

url2 = "https://github.com/KhalPrawira/Big-Data_Assignment/raw/refs/heads/main/Dataset/air_quality_data(fetch).csv"

df1 = pd.read_csv(url1)

df2 = pd.read_csv(url2)

combined_df = pd.concat([df1, df2], ignore_index=True)

print("Dataframe pertama (df1) head:")
print(df1.head())
print("\nDataframe kedua (df2) head:")
print(df2.head())
print("\nGabungan Dataframe (combined_df) head:")
print(combined_df.head())

print(f"\nJumlah baris df1: {len(df1)}")
print(f"Jumlah baris df2: {len(df2)}")
print(f"Jumlah baris gabungan: {len(combined_df)}")
# Out:
# Dataframe pertama (df1) head:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 0             Good               51           Moderate
# 1             Good               41               Good
# 2             Good               66           Moderate
# 3             Good               20               Good
# 4             Good                6               Good
#
# Dataframe kedua (df2) head:
#      Country     City  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 0  Indonesia  Bandung  156.98245    Unhealthy     17.664251  Very Unhealthy
# 1  Indonesia  Bandung  156.58333    Unhealthy     18.539856  Very Unhealthy
# 2  Indonesia  Bandung  156.25658    Unhealthy     18.659420  Very Unhealthy
# 3  Indonesia  Bandung  156.03728    Unhealthy     17.452898  Very Unhealthy
# 4  Indonesia  Bandung  155.93422    Unhealthy     15.097827       Unhealthy
#
#    Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 0        22.147495               Good      37.775806             Good
# 1        14.262523               Good      35.657997             Good
# 2         8.000928               Good      33.392437             Good
# 3         3.942486               Good      31.028370             Good
# 4         2.087198               Good      29.353820             Good
#
#    PM2.5 AQI Value PM2.5 AQI Category
# 0        156.98245     Very Unhealthy
# 1        156.58333     Very Unhealthy
# 2        156.25658     Very Unhealthy
# 3        156.03728     Very Unhealthy
# 4        155.93422     Very Unhealthy
#
# Gabungan Dataframe (combined_df) head:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya       51.0     Moderate           1.0
# 1              Brazil  Presidente Dutra       41.0         Good           1.0
# 2               Italy   Priolo Gargallo       66.0     Moderate           1.0
# 3              Poland         Przasnysz       34.0         Good           1.0
# 4              France          Punaauia       22.0         Good           0.0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good             36.0               Good            0.0
# 1            Good              5.0               Good            1.0
# 2            Good             39.0               Good            2.0
# 3            Good             34.0               Good            0.0
# 4            Good             22.0               Good            0.0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 0             Good             51.0           Moderate
# 1             Good             41.0               Good
# 2             Good             66.0           Moderate
# 3             Good             20.0               Good
# 4             Good              6.0               Good
#
# Jumlah baris df1: 23463
# Jumlah baris df2: 10416
# Jumlah baris gabungan: 33879

# %%
# Menyimpan combined_df ke dalam file CSV
output_filename = "combined_air_quality_data.csv"
combined_df.to_csv(output_filename, index=False)
print(f"Dataset gabungan telah berhasil disimpan ke '{output_filename}'")
# Out:
# Dataset gabungan telah berhasil disimpan ke 'combined_air_quality_data.csv'
