# %% [markdown]
# <a href="https://colab.research.google.com/github/KhalPrawira/Big-Data_Assignment/blob/main/Code/Analisis_Data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: Global Air Quality Polution

# %% [markdown]
# A. Pertanyaan terkait informasi Negara Indonesia
#
#
# 1. Ada berapa kota di negara Indonesia dan apa saja kota-kota yang terdapat di dalam dataset?
# 2. Berapa nilai AQI Value untuk setiap kota di Indonesia yang terdata?
# 3. Berapa nilai rata-rata AQI Value untuk setiap kota di Indonesia tersebut?
# 4. Bagaimana urutan Kota-kota tersebut dari rata-rata AQI Value terendah hingga tertinggi untuk menemukan 3 teratas?
# 5. Dari kota-kota dengan udara terbersih di Indonesia, apakah ada yang memiliki komponen polusi (misalnya PM2.5) dengan kategori di atas 'Baik' (Good)

# %%
import pandas as pd

df = pd.read_csv('https://media.githubusercontent.com/media/KhalPrawira/Big-Data_Assignment/refs/heads/main/Dataset/global%20air%20pollution%20dataset.csv')
display(df.head())
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %% [markdown]
# 1. ada berapa kota di negara Indonesia dan apa saja kota-kota yang terdapat di dalam dataset?

# %%
num_indonesia_cities = len(indonesia_cities)

display(f"Total kota di negara Indonesia: {num_indonesia_cities}")
# Out:
# 'Total kota di negara Indonesia: 379'

# %%
indonesia_cities_df = df[df['Country'] == 'Indonesia']

indonesia_cities = indonesia_cities_df['City'].unique()

display("Kota di Indonesia:")
display(indonesia_cities)
# Out:
# 'Kota di Indonesia:'
# array(['Pontianak', 'Tidore', 'Sungaipenuh', 'Tarogong', 'Binjai',
#        'Pamekasan', 'Prabumulih', 'Pringsewu', 'Lubuk Pakam', 'Mojoagung',
#        'Lamongan', 'Karang Tengah', 'Kembaran', 'Malang', 'Kutoarjo',
#        'Mataram', 'Mertoyudan', 'Driyorejo', 'Ngaglik', 'Purwakarta',
#        'Palembang', 'Pameungpeuk', 'Leuwiliang', 'Sidareja', 'Wlingi',
#        'Mlonggo', 'Ngoro', 'Ciampea', 'Balaipungut', 'Bandung',
#        'Boyolali', 'Brebes', 'Sabang', 'Sumber', 'Waingapu', 'Balung',
#        'Wanaraja', 'Sukaraja', 'Prigen', 'Sibolga', 'Sumbawa',
#        'Klangenan', 'Kebonarum', 'Kebumen', 'Sidoarjo', 'Kaliwungu',
#        'Genteng', 'Gatak', 'Cileungsi', 'Ciranjang', 'Banjarmasin',
#        'Pacet', 'Wonosobo', 'Weleri', 'Martapura', 'Surabaya',
#        'Bojonegoro', 'Bone', 'Gresik', 'Sijunjung', 'Sleman', 'Talang',
#        'Lebaksiu', 'Manado', 'Salatiga', 'Sepatan', 'Pamulang', 'Pandaan',
# ...

# %% [markdown]
# 2. Berapa nilai AQI Value untuk setiap kota di Indonesia yang terdata?

# %%
aqi_values_indonesia = indonesia_cities_df[['City', 'AQI Value']]

display("AQI Value for each city in Indonesia:")
display(aqi_values_indonesia)
# Out:
# 'AQI Value for each city in Indonesia:'
#               City  AQI Value
# 31       Pontianak         44
# 96          Tidore         21
# 193    Sungaipenuh         17
# 215       Tarogong         88
# 353         Binjai         92
# ...            ...        ...
# 23156      Welahan         96
# 23167       Muncar         37
# 23282    Margahayu         98
# 23360    Prambanan         55
# 23424    Kabanjahe         22
#
# [379 rows x 2 columns]

# %% [markdown]
# 3. Berapa nilai rata-rata AQI Value untuk setiap kota di Indonesia tersebut?

# %%
average_aqi_per_city = indonesia_cities_df.groupby('City')['AQI Value'].mean()

display("Average AQI Value for each city in Indonesia:")
display(average_aqi_per_city)
# Out:
# 'Average AQI Value for each city in Indonesia:'
# City
# Adiwerna        92.0
# Ambarawa        86.0
# Ambon           27.0
# Ambulu          54.0
# Amuntai         45.0
#                ...
# Wonogiri        51.0
# Wonopringgo    163.0
# Wonosari       174.0
# Wonosobo        81.0
# Yogyakarta      54.0
# Name: AQI Value, Length: 379, dtype: float64

# %% [markdown]
# 4. Bagaimana urutan Kota-kota tersebut dari rata-rata AQI Value terendah hingga tertinggi untuk menemukan 3 teratas?
